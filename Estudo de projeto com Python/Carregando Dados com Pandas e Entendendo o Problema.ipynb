# %% [markdown]
# # Exercício 1

# %% [markdown]
# 2. Verificando a versão Python

# %%
# !python - V
# Out:
# Python 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# >>>
#
# KeyboardInterrupt
# >>>
# KeyboardInterrupt
# >>> ^C

# %% [markdown]
# 3 . for loop

# %%
for counter in range (5):
  print(counter)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# 4. Dicionário de Frutas

# %%
example_dict = {'apple': 5, 'oranges':8, 'bananas': 13}

# %% [markdown]
# 5. convertendo dicionário em lista

# %%
dict_to_list = list(example_dict)
dict_to_list
# Out:
# ['apple', 'oranges', 'bananas']

# %% [markdown]
# 6. Combinar mais um valor na lista dict_to_list
#
# ```
# # Isto está formatado como código
# ```
#
# *Texto em itálico* *Texto em itálico*

# %%
dict_to_list = dict_to_list + ['pears']
dict_to_list
# Out:
# ['apple', 'oranges', 'bananas', 'pears']

# %% [markdown]
# ## 7. Ordenar a lista de frutas em ordem alfabética

# %%
sorted(dict_to_list)
# Out:
# ['apple', 'bananas', 'oranges', 'pears']
